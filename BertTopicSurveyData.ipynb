# %%
# Install the bertopic library
# !pip install bertopic

# Necessary

# %%
# Necessary Imports
import pandas as pd
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from umap.umap_ import UMAP
import umap
from hdbscan import HDBSCAN
import os
import json
import requests
import random
from google.colab import userdata

# %%
# Retrieve your OpenRouter API key securely
OPENROUTER_API_KEY = userdata.get('openrouter')
os.environ["OPENROUTER_API_KEY"] = OPENROUTER_API_KEY

# %%
# Load previously saved BERTopic models
positive_model = BERTopic.load("/content/drive/MyDrive/1.a SCHOOL/1.A) Grad School/7. Spring 2025/2. MIS 781/Client/positive_model")
negative_model = BERTopic.load("/content/drive/MyDrive/negative_model")

# %%
# Get top 20 topics for each group with their counts
positive_topics = positive_model.get_topic_info().head(20)
negative_topics = negative_model.get_topic_info().head(20)

# %%
# Calculate total counts for positive and negative reviews
positive_total = positive_model.get_topic_info()['Count'].sum()
negative_total = negative_model.get_topic_info()['Count'].sum()

# %%
# Enhanced Function to generate summary using OpenRouter with expanded coverage
def summarize_comments(comments):
    if not comments:
        return "No comments available to summarize."

    # Expand to a larger sample of comments (up to 500, randomly selected if too many)
    sample_size = min(500, len(comments))
    sampled_comments = random.sample(comments, sample_size)

    summary_prompt = (
        "Summarize the following customer reviews from casino guests succinctly, "
        "highlighting key insights such as what customers liked or disliked most about their experiences, "
        "specific aspects mentioned frequently (e.g., casino games, dining options, hotel stays, staff interactions, or parking), "
        "and overall sentiments or recommendations. Use as many reviews as possible for a comprehensive summary.\n\n"
    ) + "\n".join(sampled_comments)

    # Truncate prompt if it's too long for the model
    if len(summary_prompt) > 6000:
        summary_prompt = summary_prompt[:6000]  # Ensuring we don't exceed token limits

    payload = {
        "model": "google/gemini-2.0-pro-exp-02-05:free",
        "messages": [{"role": "user", "content": summary_prompt}],
        "max_tokens": 300,
        "temperature": 0.5
    }

    response = requests.post(
        url="https://openrouter.ai/api/v1/chat/completions",
        headers={
            "Authorization": f"Bearer {os.environ['OPENROUTER_API_KEY']}",
            "Content-Type": "application/json",
            "HTTP-Referer": "https://colab.research.google.com",
            "X-Title": "UNLV"
        },
        data=json.dumps(payload)
    )

    response_json = response.json()

    if "choices" in response_json and response_json["choices"]:
        return response_json["choices"][0]["message"]["content"]
    else:
        error_message = response_json.get('error', {}).get('message', 'No summary available and no error message provided.')
        return f"Error or empty response from API: {error_message}"

# %%
# Retrieve and summarize comments for the first positive topic as a quick test:
topic_id = positive_topics['Topic'].iloc[10]
topic_comments = positive_model.get_representative_docs(topic_id)
print(topic_comments)
# Out:
# {-1: [' Staff are very prompt and friend  Friendly staff  Friendly staff', 'I enjoyed playing the slots,. the machines were just very tight.  Theres hardly any good video poker machines in the place, initially when they were doing the remodeling we were told they were in the basement and they would bring them back but they havent, The food is excelent at all of the places that are open, but I feel you need a coffee shop, where you can sit down, have a more intimate feel, more variety of foods.because while im playing people always stop and ask me if you have a coffe shop and that th  My check in was weird.  When I got to the hotel my room wasnt ready so I told John at the front desk Ill go play a while and come back and get keys when the room was ready which I did.  I gathered my bags and when I went to my room I noticed their was not  see previous comments ', 'Staff are very friendly. Prompt and friendly staff.    '], 0: [' I miss the buffet!    ', ' Miss the buffet!    ', ' buffet    '], 1: ['Too much smoke     ', 'Could do without all the smoking     ', 'No smoking please     '], 2: ['Machines were very tight.     ', 'Machines were tight     ', 'Not enough machines     '], 3: [' More bartenders are needed.    ', 'Not enough bartenders     ', 'Not enough bartenders     '], 4: [' Amber at TGI Fridays is arockstar.    ', ' Very good food and service at TGI Fridays.    ', ' Need something other than tgif    '], 5: [' Steak house is very good    ', ' Steak house is great    ', ' Steak house was great    '], 6: ['Poor beverage service Hardly any beverage service on casino floor    ', 'Need more beverage staff in casino.     ', 'Need more beverage staff on casino floor     '], 7: ['I only play the slots!!!!! Food is always good.    ', 'Enjoy the variety of slot machines. Enjoyed the restaurants.    ', 'Enjoyed the variety of slot machines. Good variety of restaurants    '], 8: ['Great service Great service    Good', 'Good service Great service    ', 'Great Service Good service  Great Service  '], 9: ['It was fun! Won a little at blackjack     ', 'I like the win more because itâ€™s fun ðŸ™\x8fðŸ\x8f¾ for buffet    ', ' Great food   I did not win any money '], 10: ['Always happy at Boyd properties!     ', 'One of the better Boyd properties.     ', " ALWAYS COMFORTABLE AT BOYD'S    "], 11: ['Couldnâ€™t find a beverage server Couldnâ€™t get a Beverage server    ', 'Beverage servers werenâ€™t around much     ', 'There were no beverage servers     '], 12: [' Great food court    ', 'none new food court.    none', ' Food court was âœ…    '], 13: ['I love The Orleans     ', 'I love The Orleans!!!     ', 'Loved the Orleans!     '], 14: ['   My digital room key never worked Digital room key after app checkin never worked ', '   Digital room key didnâ€™t work Digital room key didnâ€™t work, but was helped to get one printed out ', ' Sports Bar was fun  Some improvements can be made about check in. We did online check in but they said they needed to text us when our room was ready. We waited and finally I had to go back to the desk and our room was ready. Why check in early?  '], 15: ['would rather win     ', 'Never win     ', 'Always Win     '], 16: [' Good food at Stadium    ', ' The food is excellent at the Stadium.    ', ' We ate at Stadium Club.  Itâ€™s always good.    '], 17: ['Had a great time and will return very soon Super    ', ' We will return again soon    ', 'Had a great time and will return soon     '], 18: ['New games were nice     ', 'I would like to see some new games.     ', 'The games were on fire     '], 19: ['Always fun at Fremont Casino!     ', 'Keep up the good work Fremont â€¦     ', 'We love the â€œnewâ€\x9d Fremont!     '], 20: ['Slots are very tight     ', '    Slots tight ', '    slots to tigth '], 21: [' tin lizard is great    ', ' Tin lizard is great    ', ' Tin lizard. Aaaaamazzzing    '], 22: ['Great experience Great experience    ', 'Great experience Great experience    ', 'Overall Great Experience. Good Experi ...

# %%
# # Function to summarize comments with OpenRouter API (optimized)
# def summarize_comments(comments):
#     if not comments:
#         return "No representative comments available."
#     summary_prompt = "Summarize the following customer comments succinctly:\n\n" + "\n".join(comments[:20])
#     payload = {
#         "model": "google/gemini-2.0-pro-exp-02-05:free",
#         "messages": [{"role": "user", "content": summary_prompt}],
#         "max_tokens": 150,
#         "temperature": 0.5
#     }

#     response = requests.post(
#         url="https://openrouter.ai/api/v1/chat/completions",
#         headers={
#             "Authorization": f"Bearer {os.environ['OPENROUTER_API_KEY']}",
#             "Content-Type": "application/json",
#             "HTTP-Referer": "https://colab.research.google.com",
#             "X-Title": "UNLV"
#         },
#         data=json.dumps(payload)
#     )

#     response_json = response.json()

#     if "choices" in response_json and len(response_json["choices"]) > 0:
#         return response_json["choices"][0]["message"]["content"]
#     else:
#         return "No summary reply found in the response."

# %% [markdown]
# Topic 0 is generally the most significant or the most frequent topic identified by the BERTopic model.
# The numerical values shown on the bottom axis (x-axis) represent the c-TF-IDF scores, which measure the importance of terms within that topic relative to all other topics. These scores are not directly percentages of comments but rather relative weights indicating how strongly associated these terms are with the topic.

# %%
# Generate summaries for positive topics with counts
print("\nPositive Topic Summaries with Counts:")
for _, row in positive_topics.iterrows():
    topic_id = row['Topic']
    count = row['Count']
    percentage = (count / positive_total) * 100
    topic_comments = positive_model.get_representative_docs(topic_id)
    summary = summarize_comments(topic_comments)
    print(f"\nTopic {topic_id} (Count: {count}, {percentage:.2f}%):")
    print(summary)
# Out:
# Positive Topic Summaries with Counts:
#
# Topic -1 (Count: 49459, 37.89%):
# Here's a summary of the casino guest reviews, highlighting key insights:
#
# **Key Insights:**
#
# *   **Positive:**
#     *   **Staff Friendliness and Promptness:** Overwhelmingly positive comments about staff interactions. This is the most frequently mentioned and praised aspect.
#     *   **Food Quality:** The food at the available restaurants is considered "excellent."
#
# *   **Negative:**
#     *   **Slot Machine Tightness:** Guests felt the slot machines were "very tight" (low payout).
#     *   **Lack of Video Poker:** A significant complaint is the absence of good video poker machines, despite previous promises.
#     *   **Missing Coffee Shop:** A strong desire for a more casual, intimate coffee shop with a wider variety of food options was expressed.
#     *  **Check in issues:** Room was not ready.
#
# **Frequently Mentioned Aspects:**
#
# *   **Staff:** Friendliness and promptness are consistently highlighted.
# *
#
# Topic 0 (Count: 3464, 2.65%):
# Okay, here's a succinct summary of the customer reviews:
#
# **Key Insights:**
#
# *   **Overwhelming Desire for Buffet Return:** The only feedback provided centers around a strong negative sentiment due to the absence of the buffet. Customers explicitly state they "miss the buffet."
#
# * **Dining is the Primary Focus**
# The reviews provided highlight the dining experience.
#
# **Overall Sentiment:**
#
# *   Negative, due to the missing amenity (buffet).
# * No other information is provided.
#
#
# Topic 1 (Count: 2295, 1.76%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# **Key Insight:** Overwhelmingly negative experience due to excessive smoking.
#
# **Frequently Mentioned Aspects:** Casino environment (specifically, the presence of smoke).
#
# **Customer Likes:** (None discernible from the provided reviews)
#
# **Customer Dislikes:** The pervasive presence of cigarette smoke.
#
# **Overall Sentiment/Recommendation:** Highly negative. Guests strongly desire a smoke-free environment.
#
#
# Topic 2 (Count: 1085, 0.83%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# **Key Insights & Overall Sentiment:**
#
# *   **Overwhelmingly Negative:** The reviews express a highly negative sentiment towards the casino.
# *   **Primary Complaint: "Tight" Machines:** Customers consistently complain that the slot machines do not pay out frequently enough ("tight").
# * Lack of Machines: There are not enough machines to play.
# * No positive aspects were mentioned.
#
# **Specific Aspects Mentioned:**
#
# *   **Casino Games (Slot Machines):** This is the sole focus of the negative feedback.
#
#
# Topic 3 (Count: 1031, 0.79%):
# Okay, here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Key Insights:**
#
# *   **Major Dislike:** Severe shortage of bartenders. This is the overwhelmingly dominant complaint.
# *   **Frequently Mentioned Aspect:** Bartender staffing levels.
# *   **Overall Sentiment:** Negative, due to the consistent and repeated issue impacting the customer experience.
# * No recommendations were given.
#
#
# Topic 4 (Count: 1015, 0.78%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# **Key Insights & Overall Sentiment:**
#
# *   **Positive:** TGI Fridays receives overwhelmingly positive feedback, specifically regarding both food quality and service. Amber (an employee) is singled out for exceptional service.
# *   **Negative:** There's a desire for more dining variety beyond TGI Fridays. The casino may be lacking in diverse food options.
#
# **Frequently Mentioned Aspects:**
#
# *   **Dining:** TGI Fridays is the central focus, with mentions of both food and service.
# *   **Staff Interactions:** Positive mention of a specific employee ("Amber").
#
# **Recommendations (Implicit):**
#
# *   The casino should consider expanding its dining options to cater to a wider range of preferences.
# *   TGI Friday's, and Amber in particular, are doing a great job.
#
#
# Topic 5 (Count: 1011, 0.77%):
# Here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Key Insights:**
#
# *   **Overwhelmingly Positive Dining Experience:** Customers consistently praise the steakhouse, using terms like "very good" and "great." This indicates high satisfaction with the food quality and likely the overall dining experience at the steakhouse.
# * No negative insights.
# * No other aspects of the casino were mentioned.
#
# **Overall Sentiment:**
#
# *   Extremely positive, specifically regarding the steakhouse. Customers clearly enjoyed their dining experience.
#
#
# Topic 6 (Count: 895, 0.69%):
# Okay, here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Key Insight:** Overwhelmingly negative experience due to extremely poor beverage service on the casino floor.
#
# **Frequently Mentioned Aspects:**
#
# *   **Casino Floor:** Specifically, the lack of beverage service *while playing*.
# *   **Staffing:** Insufficient number of beverage servers.
#
# **Overall Sentiment/Recommendations:**
#
# *   **Negative:** Customers are highly dissatisfied.
# *   **Recommendation:** The casino urgently needs to increase the number of beverage staff serving the casino floor. The current situation is unacceptable.
#
#
# Topic 7 (Count: 876, 0.67%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# **Key Insights:**
#
# *   **Likes:** Slot machine variety is the most prominent positive aspect, mentioned in all reviews. Food and restaurants are also consistently praised.
# *   **Dislikes:** No specific dislikes are mentioned in these limited reviews.
# *   **Frequently Mentioned Aspects:**
#     *   Slot machines (variety)
#     *   Restaurants/Food
# * No mention of hotel, staff or parking.
# *   **Overall Sentiment/Recommendations:** The reviews are overwhelmingly positive, focusing on enjoyment of the gaming and dining experiences. Guests appreciate the choices available in both areas.
#
#
# Topic 8 (Count: 863, 0.66%):
# Here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Key Insights:**
#
# *   **Overwhelmingly Positive Sentiment:** The reviews are extremely positive.
# *   **Exceptional Service:** "Great service" is the dominant, repeatedly mentioned phrase. Customers consistently praise the service they received.
# * No negative comments.
# * No mention of any other aspect of the casino.
#
# **Summary:**
#
# Customers consistently rave about the exceptional service at this casino, with "great service" being the overwhelmingly positive and frequently mentioned aspect of their experience. There is no mention of any other aspect of the casino.
#
#
# Topic 9 (Count: 854, 0.65%):
# Here's a succinct summary of the customer reviews, highlighting key insights:
#
# *   **Overall Sentiment:** Generally positive, with an emphasis on "fun."
#
# *   **Key Likes:**
#     *   Casino games (specifically Blackjack mentioned).
#     *   Buffet/Food ("Great food").
#
# *   **Key Dislikes:**
#     *   Lack of winning (for one reviewer).
#
# *   **Frequently Mentioned Aspects:**
#     *   Winning/Losing at games.
#     * Food quality.
#
# * **Recomendations:**
#     *The reviews imply a recommendation, that the casino is a fun place.
#
#
# Topic 10 (Count: 790, 0.61%):
# Here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Overall Sentiment:** Overwhelmingly positive. Customers express consistent satisfaction and comfort with Boyd properties.
#
# **Key Insights:**
#
# *   **Likes:** Customers appreciate the overall experience at Boyd properties, highlighting a sense of comfort and general satisfaction.
# *   **Specific Aspects Mentioned:**
#     *   **Boyd Properties (General):** Repeatedly mentioned, indicating strong brand loyalty and positive association with the Boyd name. One review calls out that it is one of the better properties.
# * **Recommendations:** Implicitly positive recommendations due to repeated "always" happy/comfortable statements.
#
#
# Topic 11 (Count: 781, 0.60%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# **Key Insight:** Overwhelmingly negative experience due to the complete lack of beverage service.
#
# **Frequently Mentioned Aspect:** Absence of beverage servers. Customers repeatedly mention the inability to find or get service from beverage staff.
#
# **Likes:** None mentioned.
#
# **Dislikes:** The lack of beverage service is the sole and significant complaint.
#
# **Overall Sentiment/Recommendation:** Highly negative. Customers were clearly frustrated and disappointed by the lack of basic service. The reviews strongly imply they would not recommend the casino based on this experience.
#
#
# Topic 12 (Count: 766, 0.59%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# *   **Key Insight:** The overwhelming focus is on the **food court**, with positive sentiment.
# *   **Frequently Mentioned:** "Food court" is the only aspect mentioned, described positively ("great", "✓").
# *   One review notes that the food court is not new.
# *   **Overall Sentiment:** Positive, specifically regarding the food court. There are no negative comments.
# * There are no recommendations.
#
#
# Topic 13 (Count: 764, 0.59%):
# Here's a succinct summary of the provided (extremely brief) customer reviews:
#
# **Key Insights:**
#
# *   **Overwhelmingly Positive Sentiment:** All three reviews express strong positive feelings ("love") towards The Orleans.
# *   **No Specific Aspects Mentioned:** The reviews lack detail. We don't know *why* they love The Orleans (no mention of games, food, rooms, etc.).
# * No negative comments.
#
# **Overall Sentiment/Recommendation:**
#
# *   The reviews clearly indicate a very high level of customer satisfaction and implicit recommendation.
# * There is not enough information to make recommendations for improvement.
#
#
# Topic 14 (Count: 763, 0.58%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# **Key Insights & Frequent Mentions:**
#
# *   **Digital Key Issues (Dominant Theme):** The digital room key system is unreliable and frequently fails, causing frustration for guests. This was mentioned in almost every review.
# *   **Check-in Process Problems:** The online/early check-in process is perceived as pointless or inefficient. Guests experienced delays and confusion, even after completing online check-in.
# *	**Positive Sports bar:** The sports bar was a positive.
# *   **Staff Assistance:** While the digital key failed, staff were able to assist by printing physical keys.
#
# **Overall Sentiments & Recommendations:**
#
# *   **Negative:** The overall sentiment leans negative due to the significant technical issues with the digital key and check-in process.
# *   **Needs Improvement:** Guests implicitly recommend improvements to the digital key system and a streamlining of the check-in procedure.
#
# Topic 15 (Count: 719, 0.55%):
# Here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Key Insights:**
#
# *   **Primary Focus:** The overwhelming focus of these reviews is on winning or losing at the casino games.
# *   **Likes:** One customer consistently experiences winning ("Always Win").
# *   **Dislikes:** The majority express frustration with a lack of winning ("Never win," "would rather win").
# *   **Frequently Mentioned Aspects:** Casino games (specifically, the outcome of playing them) are the only aspect mentioned.
# *   No mention of dining, hotel stay, parking, or staff.
#
# **Overall Sentiment/Recommendations:**
#
# *   The sentiment is mixed, ranging from positive (for the consistent winner) to negative (for those who don't win).
# *   The reviews suggest a potential issue with perceived fairness or win rates of the games, which significantly impacts customer satisfaction.
# * No recomendations were given.
#
#
# Topic 16 (Count: 717, 0.55%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# **Key Insights:**
#
# *   **Positive Dining Experience:** All reviews consistently praise the food quality at the "Stadium" (or "Stadium Club") restaurant.
# * The food is the main feature that is mentioned.
# * No other features of the casino are mentioned.
#
# **Overall Sentiment:**
#
# *   Highly positive regarding the dining experience at the Stadium restaurant.
#
#
# Topic 17 (Count: 711, 0.54%):
# Okay, here's a succinct summary of those (very brief) customer reviews:
#
# **Key Insights:**
#
# *   **Overwhelmingly Positive Sentiment:** All three reviews express a highly positive experience.
# *   **High Likelihood of Return:** The dominant theme is a strong intention to revisit the casino.
# * No specific dislikes.
# * No specific likes other than having a great time.
#
# **Frequently Mentioned Aspects:**
#
# *   **Return Visit:** This is the only consistently mentioned aspect, emphasizing customer satisfaction.
#
# **Overall Sentiment/Recommendations:**
#
# *   The reviews indicate a very successful and enjoyable experience, leading to strong customer loyalty and implicit recommendations (through their intention to return).
# * No negative feedback.
#
#
# Topic 18 (Count: 699, 0.54%):
# Here's a succinct summary of the casino guest reviews, highlighting key insights:
#
# **Key Insights:**
#
# *   **Focus on Games:** All reviews center around the casino games.
# *   **Mixed Feedback on Game Variety:** Guests expressed a desire for both new and existing games. One found the current selection ("new games") enjoyable, while another explicitly requested new additions.
# *    Positive experience with the performance of the games.
#
# **Overall Sentiment:**
#
# *   Generally positive, with an emphasis on the gaming experience, but with a clear call for continued updates and variety in game selection.

# %%
# Generate summaries for negative topics with counts
print("\nNegative Topic Summaries with Counts:")
for _, row in negative_topics.iterrows():
    topic_id = row['Topic']
    count = row['Count']
    percentage = (count / negative_total) * 100
    topic_comments = negative_model.get_representative_docs(topic_id)
    summary = summarize_comments(topic_comments)
    print(f"\nTopic {topic_id} (Count: {count}, {percentage:.2f}%):")
    print(summary)
# Out:
# Negative Topic Summaries with Counts:
#
# Topic -1 (Count: 28073, 41.20%):
# Here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Overall Sentiment:** Mixed. While some guests enjoyed aspects of their stay (specific restaurants, friendly check-in), a significant number of reviews point to serious service deficiencies and inconsistencies, impacting the overall experience.
#
# **Key Likes:**
#
# *   **Friendly Staff (sometimes):** Check-in/out staff were consistently praised for friendliness.
# *   **Dining (Specific Restaurants):** Excellent food was mentioned at Asia and Bugatti's.
#
# **Key Dislikes:**
#
# *   **Beverage Service (Major Issue):** Consistently poor beverage service on the casino floor was a major complaint. This included long waits, forgotten orders, difficulty finding staff, and broken self-serve ice machines.
# *   **Angry Butcher (Major Issue):** Repeatedly described as a very poor dining experience, with issues in service, food quality, and management.
# *   **Comps/Rewards:** Many felt the comp system (Boyd Points) was inadequate, especially compared to the amount of money spent. Problems with using comps at Copper Whisk, and inequality of benefits for titanium card holders.
# *   **Valet Parking:** The lack of valet service, especially on weekends, was a significant inconvenience, forcing guests to park far from their rooms.
# *   **Staffing Shortages:** Apparent understaffing was a recurring theme, impacting beverage service, table games, and general assistance
#
# Topic 0 (Count: 4960, 7.28%):
# Okay, here's a succinct summary based on the (very limited) provided customer reviews:
#
# **Key Insights:**
#
# *   **Mixed Experiences:** The reviews range from very positive to concerningly negative, indicating inconsistent experiences.
# *   **Casino Floor Enjoyment:**  Multiple guests explicitly stated they enjoyed the casino floor and the overall casino experience.
# *   **Food is a Positive:** One reviewer specifically enjoyed the food.
# *   **Low Occupancy/Empty:** A major concern is the report of an "empty casino," suggesting potential issues with atmosphere, staffing, or overall business health.
#
# **Frequently Mentioned Aspects:**
#
# *   **Casino Floor:** The primary focus of the positive reviews.
# *   **Food:** Mentioned positively by one reviewer.
#
# **Overall Sentiments/Recommendations:**
#
# *   It is hard to determine an overall sentiment. Some guests had a great experience, while others had a very poor experience.
# *   The "empty casino" comment is a significant red flag and needs to be addressed.
#
# **Limitations of this Summary:**
#
# Because of the extremely limited reviews, the summary is not comprehensive.
#
#
# Topic 1 (Count: 1345, 1.97%):
# Okay, here's a succinct summary of the customer reviews provided:
#
# **Key Insights:**
#
# *   **Overwhelming Negative Sentiment:** All reviews express dissatisfaction.
# *   **Primary Complaint: "Tight" Machines:** The dominant and only issue raised is that the slot machines are perceived as "tight," meaning they have a low payout rate or are not perceived as giving players a fair chance to win.
# * No other aspects of the casino are mentioned.
#
# **Overall Sentiment/Recommendation:**
#
# The extremely limited data suggests a strong negative perception of the casino's slot machine fairness, leading to an implied recommendation *against* playing the slots.
#
#
# Topic 2 (Count: 838, 1.23%):
# Okay, here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Key Insights & Summary:**
#
# *   **Overwhelming Demand for Buffet Return:** The dominant theme is a strong, unified desire for the casino to reinstate its buffet. Customers clearly miss this dining option and are vocal about wanting it back.
# * The buffet is the only thing mentioned.
# *No other likes or dislikes are mentioned.
# *No staff, hotel, or parking issues are brought up.
#
# **Overall Sentiment:**
#
# *   Customers are disappointed and potentially frustrated by the absence of the buffet. The repeated requests suggest this is a significant factor impacting their overall satisfaction.
#
#
# Topic 3 (Count: 820, 1.20%):
# Okay, here's a succinct summary of the customer reviews provided, highlighting key insights:
#
# **Key Insights and Summary:**
#
# *   **Major Dislike:** The overwhelming consensus is a severe lack of cocktail waitresses on the casino floor. Customers repeatedly mentioned the absence or extreme scarcity of waitresses, making it difficult or impossible to get drinks while playing.
#
# *   **Specific Aspects Mentioned Frequently:**
#     *   **Casino Floor Service:** Specifically, the availability of drinks and the presence of waitstaff.
#
# *   **Overall Sentiment:** Negative. The lack of drink service significantly detracts from the casino experience, leading to frustration. There is no recommendation, but a very clear problem.
#
# The lack of waitresses is the only insight available from the reviews.
#
#
# Topic 4 (Count: 803, 1.18%):
# Okay, here's a succinct summary of the provided customer review (singular, as only one was provided), highlighting key insights:
#
# **Overall Sentiment:** Extremely Negative. The customer has a strong aversion to Boyd properties and will not return.
#
# **Key Dislikes:**
#
# *   **Rewards Program:** This is the central complaint. The customer feels the rewards program is the "worst" and that they no longer receive points for playing. This is a significant deterrent.
# * Property Deterioration. The longer Boyd gaming owns a property the worst it gets.
#
# **Specific Aspects Mentioned:**
#
# *   **Casino Games:** Implied negatively, as the lack of rewards for playing is the main issue.
# * Boyd Properties
#
# **Recommendations:**
#
# *   The customer explicitly states "No more Boyd for me," indicating a strong recommendation *against* visiting Boyd casinos.
#
# Because only one review is available, a comprehensive summary is impossible. The sentiment is overwhelmingly negative and centered entirely on the perceived poor value of the rewards program and property deterioration.
#
#
# Topic 5 (Count: 762, 1.12%):
# Okay, here's a succinct summary of the customer reviews, focusing on the key insights you requested, based on the (limited) provided reviews:
#
# **Key Insights:**
#
# *   **Bartender Interactions are a Major Focus:** All three reviews center on the experience with bartenders. This suggests that the bar service is a significant touchpoint for customers and heavily influences their overall impression.
#
# *   **Inconsistent Bartender Service:** The reviews reveal a significant inconsistency in the quality of service provided by bartenders. Some customers found them "polite" and "pleasant," while others experienced rudeness.
#
# **Overall Sentiment:**
#
# * The reviews are very short, so the sentiment is very reliant on the bar experience.
# *   Mixed, leaning towards positive due to two positive reviews out of three, but the presence of a negative experience ("rude") indicates a potential problem area that needs attention.
#
# **Recommendations (Inferred):**
#
# *   The casino should prioritize consistent, positive customer service training for all bartenders. Addressing the reported rudeness is crucial to improving the overall customer experience.
# * Further investigation into what the bartenders are doing right and wrong.
#
#
# Topic 6 (Count: 715, 1.05%):
# Okay, here's a succinct summary of the customer reviews, focusing on the key insights:
#
# **Key Insights and Overall Sentiment:**
#
# *   **Overwhelming Negative Sentiment:** The reviews express a strong, unified negative sentiment due to one dominant factor.
# *   **Smoking is the Primary Complaint:** Customers overwhelmingly dislike the presence of smoking within the casino. This is the most frequently mentioned and most impactful aspect of their experience. Every provided review centers on this issue.
# * There is zero mention of any positive, therefore, it is safe to assume that the casino is below average.
#
# **Specific Aspects Mentioned:**
#
# *   **Smoking:** This is the sole issue mentioned, indicating it severely impacts all other aspects of the potential experience (dining, gaming, etc., are not even considered due to this).
#
# **Recommendations:**
#
# *   The implicit recommendation from all reviewers is for the casino to become non-smoking.
#
#
# Topic 7 (Count: 669, 0.98%):
# Okay, here's a succinct summary of the provided customer reviews (which, admittedly, is very limited):
#
# **Key Insights:**
#
# *   **Negative Staff Interactions:** The most prominent issue is negative interactions with casino staff. Customers specifically mention "unfriendly dealers" and a "pit boss." This suggests a potential problem with customer service training or staff morale in the gaming area.
# * **Positive Variety:** There is a reconition that it is "nice to have several options".
#
# **Overall Sentiment:**
#
# The overall sentiment is negative, driven primarily by poor customer service experiences at the gaming tables.
#
# **Recommendations (Inferred):**
#
# Based on this limited data, the casino should prioritize:
#
# *   **Customer Service Training:** Focus on improving dealer and pit boss interactions with guests, emphasizing friendliness and professionalism.
# * Investigate the cause of the unfriendly staff.
#
# Because of the limited number of reviews, it is impossible to draw more conclusions.
#
#
# Topic 8 (Count: 644, 0.95%):
# Okay, here's a succinct summary of the customer reviews provided, highlighting key insights:
#
# **Key Insights:**
#
# *   **Overwhelmingly Negative Sentiment:** All reviews express extreme dissatisfaction.
# *   **Dominant Issue: Lack of Beverage Service:** The most significant and frequently mentioned problem is the severe shortage or complete absence of beverage staff on the casino floor. This is the primary driver of negative experiences.
# * No other aspects of the casino are mentioned.
#
# **Overall Recommendation (Inferred):**
#
# Based on these reviews, customers would strongly *not* recommend this casino due to the unacceptable lack of beverage service. The casino needs to urgently address staffing levels for drink service.
#
#
# Topic 9 (Count: 613, 0.90%):
# Okay, here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Key Insights and Summary:**
#
# *   **Major Issue: Lack of Staff Visibility & Availability:** The overwhelming complaint is the severe lack of visible slot staff and infrequent beverage service. Customers repeatedly mention "never" seeing slot staff, indicating a significant problem with staffing levels or deployment.
# * The overall sentiment is negative.
# * There is no mention of any positive, only negatives.
#
# **Frequent Mentions:**
#
# *   **Slot Staff:** Absence is the only mention.
# *   **Beverage Staff:** Infrequent presence.
#
#
# Topic 10 (Count: 547, 0.80%):
# Here's a succinct summary of the customer reviews, highlighting key insights:
#
# **Overall Sentiment:** The reviews show a highly mixed experience, with opinions ranging from negative to positive.
#
# **Key Insights:**
#
# *   **Food Quality:** A major point of contention. One review explicitly states the food was "not good," while another says "good food." The numerical rating "5" for food quality suggests it is average or slightly below, in contrast to the "good food" comments.
# *   **Service:** Also inconsistent. "Slow service" is mentioned, contrasting with "good service." The numerical rating of "9" for service indicates a very positive experience in that instance, while the "Slow Service" comment indicates the total opposite.
#
# **Frequently Mentioned Aspects:**
#
# *   **Food and Service:** These are the only aspects directly mentioned, making them the central focus of these reviews.
#
# **Recommendations:**
# There is not enough information to accurately gauge a recommendation.
#
#
# Topic 11 (Count: 524, 0.77%):
# Okay, here's a succinct summary of the customer reviews provided, highlighting key insights:
#
# **Key Insights and Overall Sentiment:**
#
# *   **Overwhelming Negative: Smoking.** The dominant theme across all reviews is the pervasive and unpleasant cigarette smoke throughout the casino, even extending into areas designated as non-smoking. This significantly detracts from the overall experience.
#
# **Specific Aspects Mentioned:**
#
# *   **Casino Environment:** The primary focus is the casino's air quality, specifically the presence of strong cigarette smoke and smell.
# * No other aspects of the casino such as dining, hotel stays, or staff are mentioned.
#
# **Recommendations:**
#
# *   While not explicitly stated, the reviews strongly imply a need for the casino to address its air quality and smoking policies to improve customer satisfaction.
#
#
# Topic 12 (Count: 521, 0.76%):
# Okay, here's a succinct summary of the customer reviews, focusing on the key insights:
#
# **Key Insights and Overall Sentiment:**
#
# *   **Overwhelming Dislike:** The dominant theme is a strong dissatisfaction with the lack of table games. Customers repeatedly express disappointment about the limited availability and variety of table games.
# *   **Specific Aspect Mentioned Frequently:** The casino's table game offerings (or lack thereof) are the sole focus of these reviews. There is a severe shortage of the number of tables and the diversity of the table games.
# * No other aspects of the casino experience are mentioned.
#
# **Overall, the reviews indicate a significant deficiency in the casino's table game offerings, leading to negative customer experiences and a likely reluctance to recommend or return.**
#
#
# Topic 13 (Count: 491, 0.72%):
# Okay, here's a succinct summary of the customer reviews provided, highlighting key insights:
#
# **Key Insights:**
#
# *   **Overwhelmingly Negative Sentiment:** The dominant theme is a strong sense of disappointment and frustration due to a perceived lack of winning.
# *   **Focus on Payout/Winning:** The reviews exclusively focus on the inability to win money at the casino games. There's no mention of any other aspect of the casino experience (dining, hotel, staff, etc.).
# *   No wins.
#
# **Overall Sentiment/Recommendation:**
#
# The reviews indicate a highly negative experience centered entirely around the perceived impossibility of winning. The implicit recommendation is strongly negative – customers are questioning whether winning is even possible.
#
#
# Topic 14 (Count: 473, 0.69%):
# Okay, here's a succinct summary of the provided customer reviews, focusing on key insights and frequently mentioned aspects:
#
# **Overall Sentiment:** The reviews express overwhelmingly **negative** experiences, primarily centered around housekeeping issues. There's a strong sense of dissatisfaction and a feeling that basic service expectations were not met.
#
# **Key Problems (Frequently Mentioned):**
#
# *   **Housekeeping (Major Issue):**
#     *   Rooms were consistently not cleaned for multiple days.
#     *   Towels were not replenished.
#     *   Toilet paper was not replenished.
#     *   Beds were not made.
#     *   Tips were taken even when service was not provided.
# * **Communication**
#     *Complaints to the front desk, while acknowledged, did not always resolve the immediate problem efficiently.
#
# **What Customers Disliked Most:**
#
# *   The core issue is the **failure to provide basic housekeeping services**, leading to unsanitary and uncomfortable conditions.
# *   The fact that tips were taken *without* service being rendered adds insult to injury, suggesting a potential systemic problem or lack of accountability within the housekeeping department.
#
# **Recommendations:**
#
# *   Based on these few reviews, potential guests should be **highly cautious** about the cleanliness and housekeeping service at this casino/hotel.
# * The reviews did not mention anything positive.
#
# In essence, these reviews paint a picture of a casino/hotel struggling significantly with its housekeeping operations, leading to
#
# Topic 15 (Count: 452, 0.66%):
# Okay, let's break down these "reviews":
#
# **Summary of Customer Reviews:**
#
# *   **Key Insight:** The overwhelming focus is on the elevators. Customers are either stating the existence of elevators, or, more likely, expressing a strong, unstated opinion *about* the elevators.
# *   **Frequently Mentioned Aspect:** Elevators. This is the only aspect mentioned.
# *   **Likes/Dislikes:** Impossible to definitively say without more context, but the repetition strongly suggests a negative experience. It's highly probable that customers disliked something about the elevators (e.g., long wait times, overcrowding, malfunctions, cleanliness, or slow speed). The single word could be shorthand for a longer complaint.
# *   **Overall Sentiment/Recommendation:** Likely negative. The repetitive, single-word nature of the "reviews" suggests frustration and a lack of desire to elaborate, pointing towards a poor experience related to the elevators. It is unlikely that any of these guests would recommend the casino.
#
# **In essence, the casino has a significant problem with its elevators that is negatively impacting the guest experience.** The management should prioritize investigating and addressing the elevator issues immediately.
#
#
# Topic 16 (Count: 443, 0.65%):
# Okay, I understand.  The problem is that all the "reviews" you've provided are references to *other* comments ("See above comments", "See previous comments").  Without the actual content of those previous comments, I cannot summarize anything.
#
# To get a useful summary, I need the *text* of the customer reviews. Think of it like this: I can't summarize a book if all you tell me is "See Chapter 1", "See Chapter 2", etc. I need the words *in* those chapters.
#
# **To help you, here's what I would do if I *did* have the reviews, and this is what you should look for when providing the reviews:**
#
# 1.  **Identify Key Themes:** I'd read through each review and look for recurring topics. These would likely include:
#     *   **Gaming Experience:** Types of games (slots, table games, poker), fairness, payout rates, atmosphere of the casino floor.
#     *   **Hotel Accommodations:** Room cleanliness, comfort, amenities, views, noise levels.
#     *   **Dining:** Variety of restaurants, food quality, service speed, pricing.
#     *   **Customer Service:** Friendliness and helpfulness of staff (dealers, hotel staff, restaurant servers, customer service representatives), responsiveness to complaints.
#     *   **Amenities:** Pool, spa, entertainment venues, shops.
#     *   **Parking:**
#
# Topic 17 (Count: 433, 0.64%):
# Okay, here's a succinct summary of the customer reviews provided, highlighting key insights:
#
# **Key Insights and Summary:**
#
# *   **Overwhelmingly Negative Experience Centered on Lack of Beverage Service:** The dominant and only theme across all reviews is the complete absence of beverage servers on the casino floor. Customers repeatedly state they "never" saw one.
#
# *   **Specific Aspects Mentioned:**
#     *   **Casino Games (Implied):** While not directly stated, the context implies these reviews are from people playing casino games, as that's where beverage service is typically expected.
#     *   **Beverage Service:** The complete lack of this service is the sole focus.
#
# *   **Overall Sentiment:** Extremely negative. The repetition of "never" emphasizes the customers' frustration and disappointment. There is an implied expectation of beverage service that was entirely unmet.
#
# * No recommendations are given, but is implied that future guests should not expect beverage service.
#
#
# Topic 18 (Count: 398, 0.58%):
# Okay, here's a summary based on the (admittedly very limited) reviews provided:
#
# **Summary of Customer Reviews:**
#
# This set of reviews provides a highly polarized and incomplete picture of the casino. We have extremes, but no detail.
#
# *   **Key Insights:**
#     *   **Mixed Experiences:** The reviews range from positive ("Nice place to visit," "My visit was swell") to negative ("Not the place for us again"). This indicates inconsistent experiences, with some guests enjoying their time and others being dissatisfied.
#     *   **Lack of Specificity:** The reviews offer *no* specific details about *why* the experiences were positive or negative. We don't know what aspects (games, food, rooms, service, etc.) contributed to these opinions.
#
# *   **Frequently Mentioned Aspects:** None. No specific aspects of the casino are mentioned.
#
# *   **Overall Sentiments/Recommendations:**
#     *   Some guests had a positive, enjoyable experience.
#     *   Some guests were dissatisfied and would not return.
#     *   It is impossible to give a recommendation due to the lack of detail.
#
# **In short, based on *only* these three reviews, all we can say is that the casino provides inconsistent experiences, with some guests enjoying it and others not. There is insufficient information to determine the causes of these varying opinions, or to highlight any specific strengths or weaknesses.** More reviews are needed to provide any meaningful insight

# %%
# Visualize the distribution of positive topics clearly
positive_model.visualize_barchart(top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fc64a0ac-dd25-4666-80ae-f2fa991f6d7e" class="plotly-graph-div" style="height:1250px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc64a0ac-dd25-4666-80ae-f2fa991f6d7e")) {                    Plotly.newPlot(                        "fc64a0ac-dd25-4666-80ae-f2fa991f6d7e",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012830531275159799,0.01654986010167916,0.016684973213060623,0.01804461115354642,0.041841013985172724],"y":["wish buffet  ","miss  ","bring buffet  ","miss buffet  ","buffet  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01285987316723704,0.01561922751906793,0.016460997655668864,0.031186134977559673,0.03435167029046576],"y":["cigarette  ","non  ","non smoking  ","smoke  ","smoking  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.008709366758663697,0.012243933509299934,0.01775901461271385,0.019135654005609914,0.03365162342568689],"y":["machine  ","new machines  ","machines tight  ","tight  ","machines  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008486459247650003,0.010034403915699604,0.01436186146505848,0.04464548833397001,0.048925488570128774],"y":["bartenders great  ","great bartender  ","bar  ","bartenders  ","bartender  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.013095324632913586,0.02412375970463297,0.036041430380782544,0.042402938195204534,0.042867614255449875],"y":["tgifridays  ","fridays  ","tgi fridays  ","tgif  ","tgi  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.014603065820285453,0.028059372798708824,0.03386316353677968,0.03687545048132895,0.06496523954259532],"y":["shake  ","house  ","steakhouse  ","steak house  ","steak  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.007827271564991564,0.00875915175120303,0.009186623866894799,0.01003662693656323,0.010076214797753209],"y":["beverage service  ","drink  ","casino floor  ","casino  ","beverage  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007579370963381501,0.008057458328408013,0.011945252726187554,0.01525915589542183,0.01826754175110487],"y":["tight  ","machines  ","slot  ","slot machines  ","slots  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.03824294055116801,0.04161540871127346,0.045466274738474526,0.04568049311420861,0.04769162352557893],"y":["customer service  ","service great  ","good service  ","service good  ","great service  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.008511862445940701,0.009771356739567935,0.02370162950304045,0.0241281485880491,0.031474422986861136],"y":["wish won  ","did win  ","won  ","didnt win  ","win  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.012704311650579697,0.015024051200917822,0.016821924641086398,0.02077845526042636,0.05894286954267455],"y":["boyd rewards  ","boyd properties  ","properties  ","boyds  ","boyd  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.017791606949736256,0.02803370776160665,0.02902032101216789,0.03379892801387068,0.03506572687975752],"y":["beverage  ","server  ","beverage server  ","beverage servers  ","servers  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.016839823787783082,0.017686559277684706,0.038352970434508867,0.07596984188724891,0.07597561660562728],"y":["new  ","cou ...

# %%
# Visualize the distribution of negative topics clearly
negative_model.visualize_barchart(top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="